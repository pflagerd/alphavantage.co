# %% [markdown]
# Experiment to retrieve BA data

# %%
import requests

thing = requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=BA&apikey=MQ4RIQTF8CTS5RMM").json()

print(thing)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'BA', '3. Last Refreshed': '2024-04-24', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2024-04-24': {'1. open': '176.5000', '2. high': '177.6400', '3. low': '162.7400', '4. close': '164.3300', '5. volume': '20889273'}, '2024-04-23': {'1. open': '170.9500', '2. high': '171.1800', '3. low': '168.4300', '4. close': '169.1800', '5. volume': '7632123'}, '2024-04-22': {'1. open': '169.8200', '2. high': '172.1500', '3. low': '168.1600', '4. close': '170.4800', '5. volume': '4724887'}, '2024-04-19': {'1. open': '170.0000', '2. high': '172.0000', '3. low': '169.6500', '4. close': '169.8200', '5. volume': '4693869'}, '2024-04-18': {'1. open': '169.4800', '2. high': '172.0400', '3. low': '169.0950', '4. close': '170.2300', '5. volume': '5123020'}, '2024-04-17': {'1. open': '170.0000', '2. high': '170.8500', '3. low': '168.1215', '4. close': '170.2100', '5. vo
# ...

# %%
print(thing["Time Series (Daily)"])
# Out:
# {'2024-04-24': {'1. open': '176.5000', '2. high': '177.6400', '3. low': '162.7400', '4. close': '164.3300', '5. volume': '20889273'}, '2024-04-23': {'1. open': '170.9500', '2. high': '171.1800', '3. low': '168.4300', '4. close': '169.1800', '5. volume': '7632123'}, '2024-04-22': {'1. open': '169.8200', '2. high': '172.1500', '3. low': '168.1600', '4. close': '170.4800', '5. volume': '4724887'}, '2024-04-19': {'1. open': '170.0000', '2. high': '172.0000', '3. low': '169.6500', '4. close': '169.8200', '5. volume': '4693869'}, '2024-04-18': {'1. open': '169.4800', '2. high': '172.0400', '3. low': '169.0950', '4. close': '170.2300', '5. volume': '5123020'}, '2024-04-17': {'1. open': '170.0000', '2. high': '170.8500', '3. low': '168.1215', '4. close': '170.2100', '5. volume': '8162632'}, '2024-04-16': {'1. open': '168.1400', '2. high': '170.6400', '3. low': '167.7500', '4. close': '170.5500', '5. volume': '7986725'}, '2024-04-15': {'1. open': '170.7400', '2. high': '171.1800', '3. low': '
# ...

# %%
baRawTimeSeries = thing["Time Series (Daily)"]

for key,value in baRawTimeSeries.items():
    print(key, value["4. close"], value["5. volume"])
# Out:
# 2024-04-24 164.3300 20889273
# 2024-04-23 169.1800 7632123
# 2024-04-22 170.4800 4724887
# 2024-04-19 169.8200 4693869
# 2024-04-18 170.2300 5123020
# 2024-04-17 170.2100 8162632
# 2024-04-16 170.5500 7986725
# 2024-04-15 167.8200 6490657
# 2024-04-12 169.5500 7568297
# 2024-04-11 173.3600 7625110
# 2024-04-10 174.6300 9727732
# 2024-04-09 178.1200 11224063
# 2024-04-08 181.5600 6080198
# 2024-04-05 183.1400 4021683
# 2024-04-04 183.2900 6413800
# 2024-04-03 184.9200 6575329
# 2024-04-02 188.0400 4463599
# 2024-04-01 189.5000 4992634
# 2024-03-28 192.9900 4471666
# 2024-03-27 191.9500 7372795
# 2024-03-26 187.5000 8972192
# 2024-03-25 191.4100 12952957
# 2024-03-22 188.8500 7826970
# 2024-03-21 187.7000 7436385
# 2024-03-20 187.7800 12770004
# 2024-03-19 181.1400 7648033
# 2024-03-18 179.8400 9497831
# 2024-03-15 182.5300 10800678
# 2024-03-14 181.1500 9967847
# 2024-03-13 182.3500 10133813
# 2024-03-12 184.2400 18644036
# 2024-03-11 192.4900 13941911
# 2024-03-08 198.4900 9010175
# ...
